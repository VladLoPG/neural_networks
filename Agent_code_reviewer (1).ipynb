# %% [markdown]
# <a href="https://colab.research.google.com/github/VladLoPG/Lobanov-Programming-HSE/blob/main/deep-learning/Agent_code_reviewer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain_groq -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 12.1 MB/s eta 0:00:00

# %%
from langchain_groq import ChatGroq
from datetime import datetime

# %%
class Agent:
    def __init__(self, name, role, api_key, model="llama-3.1-8b-instant"):
        self.name = name
        self.role = role
        self.llm = ChatGroq(
            temperature=0.7,
            model_name=model,
            groq_api_key=api_key,
            max_tokens=1000
        )

    def execute(self, task, context=""):
        prompt = f"""
ROLE: You are {self.name}, {self.role}
CONTEXT: {context}
TASK: {task}

Requirements:
1. Use English
2. Properly format your answer using markdown
3. Be informative and up to the point

Answer:
"""
        response = self.llm.invoke(prompt)
        return response.content

# %%
class Proxy:
  '''
  Класс принимает агентов, их задачи и код для ревью
  '''
  def __init__(self, agents, tasks, code):
    self.agents = agents
    self.tasks = tasks
    self.code = code
    self.results = {}

  def kickoff(self):
    for i, (agent, task_desc) in enumerate(zip(self.agents, self.tasks), 1):
      print(f"[TASK {i}/{len(self.tasks)}] {agent.name}")
      print(f"  Description: {task_desc}")
      if agent.name == 'Code analyzer': # чтобы только аналитик кода имел к нему доступ
        context = self.code
      start_time = datetime.now()
      result = agent.execute(task_desc, context)
      end_time = datetime.now()

      execution_time = (end_time - start_time).total_seconds()

      print(f"  Len: {len(result)} chars")
      print(f"  Time: {execution_time:.2f} sec")
      print(f"\033[92m  Answer: {result}\n\033[0m")

      self.results[agent.name] = result
      context = f"\n\n--- Model Answer {agent.name} ---\n{result}"

    return self.results

# %%
from google.colab import userdata

API_KEY = userdata.get('groq_testing')

# %%
# загружаем код для ревью
from pathlib import Path

file_path = Path("bad_code.py");
file_content = file_path.read_text()

# %%
# инструкции агентов
code_analysis_prompt = """
You are a Python code analyzer. Your tasks:
- Check PEP8 style issues
- Identify bugs
- Suggest optimizations
Your answer is strictly a JSON object with keys: pep8_issues, bugs, optimizations. You must not provide any additional text
"""

report_prompt = '''
You are a professional code reviewer. You create concise reports on the code quality based on the json analysis from your colleague.
The JSON has keys pep8_issues, bugs, optimizations. Consider them and create a report on how to improve the code.
'''

# %%
# Создаем агентов
agents = [
    Agent("Code analyzer", "analyzer of code according to pep8, bugs and optimizations", API_KEY),
    Agent("Report maker", "producer of reports on how to improve code", API_KEY)
]

# %%
# Определяем задачи
tasks = [
    code_analysis_prompt,
    report_prompt
]

# %%
# Создаем и запускаем прокси
proxy = Proxy(agents, tasks, file_content)
results = proxy.kickoff()
# Out:
# [TASK 1/2] Code analyzer
#   Description:
# You are a Python code analyzer. Your tasks:
# - Check PEP8 style issues
# - Identify bugs
# - Suggest optimizations
# Your answer is strictly a JSON object with keys: pep8_issues, bugs, optimizations. You must not provide any additional text
#
#   Len: 4421 chars
#   Time: 1.59 sec
#   Answer: ```json
# {
#     "pep8_issues": [
#         {
#             "code": "import sys,os,time",
#             "issue": "Unused import",
#             "suggestion": "Remove unused imports or import only the required modules"
#         },
#         {
#             "code": "def DoStuff(x,y,flag=False):",
#             "issue": "Function name should be lowercase with words separated by underscores",
#             "suggestion": "Rename function to do_stuff"
#         },
#         {
#             "code": "def DoStuff(x,y,flag=False):",
#             "issue": "Function parameters should be separated by two spaces",
#             "suggestion": "Modify function definition to follow PEP8"
#         },
#         {
#             "code": "result=[]",
#             "issue": "List comprehension should be used instead of explicit list creation",
#             "suggestion": "Use list comprehension to create list"
#         },
#         {
#             "code": "for i in range(0,len(x))",
#             "issue": "Range function should not use explicit 0 as start value",
#             "suggestion": "Modify range function to start from 0 implicitly"
#         },
#         {
#             "code": "if flag==True",
#             "issue": "Boolean comparison should be simplified to if flag",
#             "suggestion": "Simplify boolean comparison"
#         },
#         {
#             "code": "class myclass:",
#             "issue": "Class name should be capitalized",
#             "suggestion": "Rename class to MyClass"
#         },
#         {
#             "code": "def __init__(self,data={}):",
#             "issue": "Dictionary default value should be a function",
#             "suggestion": "Use a function to return an empty dictionary"
#         },
#         {
#             "code": "def add(self,key,value):",
#             "issue": "Function name should be lowercase with words separated by underscores",
#             "suggestion": "Rename function to add_item"
#         },
#         {
#             "code": "if key in self.data.keys():",
#             "issue": "Dictionary keys method should be used, which returns a view object displaying a list of all the available keys in the dictionary",
#             "suggestion": "Use dictionary keys method"
#         },
#         {
#             "code": "del self.data[key]",
#             "issue": "Dictionary pop method should be used to remove the item and return its value",
#             "suggestion": "Use dictionary pop method to remove item"
#         },
#         {
#             "code": "def slowSum(self,n):",
#             "issue": "Function name should be lowercase with words separated by underscores",
#             "suggestion": "Rename function to calculate_sum"
#         },
#         {
#             "code": "s=0",
#             "issue": "Variable assignment should be done in a single line for simple cases",
#             "suggestion": "Simplify variable assignment"
#         },
#         {
#             "code": "for i in range(n):",
#             "issue": "Range function should be used with a single variable",
#             "suggestion": "Modify range function to use a single variable"
#         },
#         {
#             "code": "for j in range(n):",
#             "issue": "Range function should be used with a single variable",
#             "suggestion": "Modify range function to use a single variable"
#         },
#         {
#             "code": "if __name__==\"__main__\":",
#             "issue": "Incorrect placement of if __name__==\"__main__\"",
#             "suggestion": "Move if __name__==\"__main__\" to the top of the file"
#         }
#     ],
#     "bugs": [
#         {
#             "code": "b=[4,5]",
#             "issue": "Different length lists",
#             "suggestion": "Ensure lists have the same length"
#         },
#         {
#             "code": "c=DoStuff(a,b,flag=\"yes\")",
#             "issue": "Wrong type for flag parameter",
#             "suggestion": "Pass a boolean value for flag parameter"
#         },
#         {
#             "code": "obj.add(\"a\",1)",
#             "issue": "Adding duplicate key",
#             "suggestion": "Handle duplicate key addition"
#         },
#         {
#             "code": "obj.remove(\"missing\")",
#             "issue": "KeyError",
#             "suggestion": "Handle KeyError"
#         }
#     ],
#     "optimizations": [
#         {
#             "code": "def slowSum(self,n):",
#             "issue": "Slow algorithm",
#             "suggestion": "Use a more efficient algorithm, such as the formula for the sum of an arithmetic series"
#         }
#     ]
# }
# ```
#
# [TASK 2/2] Report maker
#   Description:
# You are a professional code reviewer. You create concise reports on the code quality based on the json analysis from your colleague.
# The JSON has keys pep8_issues, bugs, optimizations. Consider them and create a report on how to improve the code.
#
#   Len: 2679 chars
#   Time: 0.95 sec
#   Answer: **Code Quality Improvement Report**
# =====================================
#
# **Introduction**
# ---------------
#
# The provided JSON analysis contains issues related to code quality, bugs, and optimizations. This report aims to summarize the findings and provide actionable recommendations for improving the code.
#
# **PEP8 Issues**
# --------------
#
# The code contains several PEP8 issues, which are guidelines for writing Python code. These issues include:
#
# * Unused imports
# * Incorrect function names and parameters
# * List comprehension usage
# * Simplified boolean comparisons
# * Class and function naming conventions
# * Dictionary default value usage
# * Simplified variable assignments
#
# **Recommendations:**
#
# * Remove unused imports to improve code readability and maintainability.
# * Rename functions and variables to follow PEP8 naming conventions.
# * Use list comprehension instead of explicit list creation.
# * Simplify boolean comparisons to improve code readability.
# * Use dictionary keys method to access dictionary keys.
# * Use dictionary pop method to remove items from dictionaries.
# * Rename functions to follow PEP8 naming conventions.
#
# **Bugs**
# ------
#
# The code contains several bugs that need to be addressed:
#
# * Different length lists
# * Wrong type for flag parameter
# * Adding duplicate keys
# * Handling KeyError
#
# **Recommendations:**
#
# * Ensure lists have the same length to prevent bugs.
# * Pass a boolean value for the flag parameter to avoid bugs.
# * Handle duplicate key addition to prevent bugs.
# * Handle KeyError to prevent bugs.
#
# **Optimizations**
# --------------
#
# The code contains a slow algorithm that can be optimized:
#
# * The `slowSum` function can be optimized using a more efficient algorithm, such as the formula for the sum of an arithmetic series.
#
# **Recommendations:**
#
# * Use a more efficient algorithm, such as the formula for the sum of an arithmetic series, to optimize the `slowSum` function.
#
# **Conclusion**
# --------------
#
# This report summarizes the issues found in the code analysis. By addressing the PEP8 issues, bugs, and optimizations, the code quality can be improved. The recommended changes will enhance code readability, maintainability, and performance.
#
# **Action Items:**
#
# * Address PEP8 issues by removing unused imports, renaming functions and variables, and simplifying boolean comparisons.
# * Fix bugs by ensuring lists have the same length, passing a boolean value for the flag parameter, handling duplicate key addition, and handling KeyError.
# * Optimize the `slowSum` function using a more efficient algorithm.
#
# By implementing these changes, the code quality will be significantly improved, making it more maintainable, efficient, and reliable.
